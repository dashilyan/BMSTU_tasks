# %% [markdown]
# # **Лабораторная работа 2. Методы анализа параметров компонентов моделей функционирования КИС**

# %% [markdown]
# ## 1. Идентификация распределений

# %% [markdown]
# **Задание 1.** Время безотказной работы 50 блоков питания (в часах) представлено в выборке:
#
# 12.4, 3.2, 45.7, 8.1, 22.3, 5.6, 31.8, 15.2, 7.4, 28.9,
# 42.1, 2.5, 18.3, 9.7, 36.4, 11.2, 24.5, 6.8, 52.3, 14.1,
# 19.7, 4.3, 38.2, 21.5, 10.8, 27.6, 33.1, 8.9, 16.4, 29.5,
# 13.7, 41.2, 23.8, 5.1, 47.3, 18.9, 7.2, 35.6, 20.4, 9.3,
# 25.7, 14.8, 30.2, 11.5, 39.4, 17.1, 6.3, 48.5, 22.7, 12.9
#
# Выдвинуть гипотезу $H_0$: выборка имеет экспоненциальное распределение с неизвестным параметром $\lambda$.
#
# Оценить параметр $\lambda$. Проверить гипотезу с помощью критерия согласия Колмогорова-Смирнова на уровне значимости $\alpha = 0.05$. Построить график эмпирической функции распределения и теоретической функции экспоненциального распределения с оцененным параметром. Сделать вывод о принятии или отклонении гипотезы.

# %% [markdown]
# **Задание 2.** На web-сервере зарегистрированы моменты поступления запросов (в секундах от начала наблюдения):
#
#
# 0.3, 1.8, 2.2, 3.5, 4.1, 5.7, 6.3, 7.9, 8.4, 10.2,
# 11.5, 12.8, 13.4, 14.9, 15.3, 17.1, 18.6, 19.2, 21.4, 22.7,
# 24.0, 25.3, 26.8, 27.2, 29.5, 31.0, 32.4, 33.7, 34.9, 36.2
#
# Вычислить интервалы между последовательными событиями $\tau_i = t_{i+1} - t_i$. Выдвинуть гипотезу $H_0$: поток является рекуррентным (интервалы независимы и одинаково распределены). Проверить гипотезу о независимости интервалов:
# - Определить корреляции для пар $(\tau_i, \tau_{i+1})$.
# - Вычислить коэффициент автокорреляции первого порядка $\rho_1 = \frac{\sum (\tau_i - \bar{\tau})(\tau_{i+1} - \bar{\tau})}{\sum (\tau_i - \bar{\tau})^2}$.
# - Проверить значимость отличия $\rho_1$ от нуля с помощью критерия Стьюдента при $\alpha = 0.05$.
#
# Проверить гипотезу об одинаковом распределении интервалов (стационарности):
# - Разбить выборку на две части (первые 15 и последние 15 интервалов).
# - Проверить гипотезу о равенстве средних с помощью критерия Манна-Уитни или t-критерия.
#
# Сделать вывод: можно ли считать данный поток потоком с ограниченным последействием, без последействия.

# %% [markdown]
# **Задание 3.**
#
# Даны две выборки интервалов времени между событиями (в условных единицах):
#
# Выборка A:
#
# 1.2, 0.8, 1.5, 0.9, 1.1, 1.3, 0.7, 1.4, 0.6, 1.0,
# 1.2, 0.9, 1.3, 1.1, 0.8, 1.5, 0.7, 1.2, 1.4, 0.9
#
# Выборка B:
#
# 0.3, 2.1, 0.4, 2.5, 0.2, 2.8, 0.5, 2.3, 0.6, 1.9,
# 0.4, 2.4, 0.3, 2.7, 0.5, 2.2, 0.4, 2.6, 0.3, 2.9
#
#
# Для каждой выборки оценить интенсивность потока $\lambda$.
#
# Вычислить коэффициент вариации $k_v$ для обеих выборок. Выдвинуть гипотезу $H_0$: поток простейший (интервалы распределены экспоненциально, $k_v = 1$).
#
# На уровне значимости $\alpha = 0.05$ определить, для какой выборки гипотеза о простейшем потоке отвергается.
#
# Для выборки, где $H_0$ отвергается, подобрать распределение Эрланга. Визуализировать полученные результаты.

# %% [markdown]
# **Задание 4.**
#
# Сгенерировать простейший (пуассоновский) поток с интенсивностью $\lambda = 5$ событий в единицу времени (не менее 10000 событий).
#
# Получить поток Эрланга 3-го порядка, взяв каждое 3-е событие исходного потока.
#
# Для полученного потока:
#
# - Построить гистограмму интервалов.
# - Оценить параметры распределения.
# - Наложить на гистограмму теоретическую плотность распределения Эрланга 3-го порядка: $f(t) = \frac{\lambda (\lambda t)^{2} e^{-\lambda t}}{2!}$.
# - Проверить гипотезу о том, что поток является рекуррентным (проверить независимость интервалов).
# - Сравнить коэффициент вариации полученного потока с теоретическим значением $k_v = 1/\sqrt{k}$.

# %% [markdown]
# **Задание 5**
#
# Поток отказов вычислительного узла описывается потоком Пальма. Плотность распределения интервалов между отказами имеет вид (гиперэкспоненциальное распределение) :
# $$f(t)=0.3\cdot 2e^{-2t}+0.7\cdot 0.5 e^{-0.5t},t\geq 0$$
#
# Найти $M[T]$ и $D[T]$ интервала между событиями.
#
# Вычислить коэффициент вариации $k_v = \sigma / M[T]$. Сравнить с экспоненциальным случаем ($k_v = 1$) и сделать вывод о характере потока.
#
# Найти преобразование Лапласа-Стилтьеса распределения интервалов $\tilde{F}(s)$.
#
# Используя обращение ПЛС, найти функцию распределения $F(t)$ и построить ее график.
#
# Сгенерировать выборку интервалов по данному распределению и проверить, что выборочный коэффициент вариации близок к теоретическому.

# %% [markdown]
# **Задание 6.** Имеются две независимые выборки времен наработки на отказ однотипных устройств, но работающих в разных условиях (нормальные и тяжелые условия):
#
# Выборка A (нормальные условия):
#
# 145, 234, 67, 312, 189, 256, 98, 178, 345, 123,
# 287, 156, 201, 89, 267, 134, 298, 176, 215, 92
#
# Выборка B (тяжелые условия):
#
# 56, 123, 45, 89, 67, 112, 34, 78, 95, 43,
# 132, 76, 54, 101, 82, 63, 117, 48, 71, 88
#
# Выдвинуть гипотезу $H_0$: $\lambda_A = \lambda_B$ (интенсивности отказов равны) против альтернативы $H_1$: $\lambda_A < \lambda_B$ (в тяжелых условиях интенсивность выше). Проверить гипотезу на уровнях значимости $\alpha = 0.05$ и $\alpha = 0.01$.
#
# Проверить гипотезу о соответствии выборок экспоненциальному закону распределения, для распределения отличного от экспоненциального подобрать подходящее распределение Эрланга.

# %% [markdown]
# ## 2. Нахождение плотности распределения суммы независимых случайных величин

# %% [markdown]
# **Задача 1**
#
# Две независимые случайные величины $X$, $Y$ и $Z$ распределены равномерно:
#
# $X \sim U[0, 3]$ (плотность $f_X(x) = 1/3$ на $[0,3]$)
#
# $Y \sim U[0, 5]$ (плотность $f_Y(y) = 1/5$ на $[0,5]$)
#
# $Z \sim U[0, 2]$ (плотность $f_Z(z) = 1/2$ на $[0,2]$)
#
# Найти плотность распределения $Z = X + Y - Z$ и ее математическое ожидание (теоретически, экспериментально).

# %% [markdown]
# **Задача 2**
#
# Независимые случайные величины:
#
# $X$ равномерно распределена на $[0, 4]$
#
# $Y$ имеет показательное распределение с параметром $\lambda = 0.5$ (плотность $f_Y(y) = 0.5e^{-0.5y}, y \ge 0$)
#
# Найти плотность распределения $Z = X + Y$ и ее математическое ожидание (теоретически, экспериментально).

# %% [markdown]
# **Задача 3**
#
# Независимые нормально распределенные величины:
#
# $X \sim N(5, 2)$ (матожидание 5, дисперсия 2)
#
# $Y \sim N(3, 1)$ (матожидание 3, дисперсия 1)
#
# Найти распределение $Z = X + Y$, его плотность, математическое ожидание и дисперсию (теоретически, экспериментально.

# %% [markdown]
# **Задача 4**
#
# Независимые величины:
#
# $X$ равномерно распределена на $[-1, 1]$
#
# $Y$ имеет стандартное нормальное распределение $N(0, 1)$
#
# Найти распределение $Z = X + Y$. Вычислить $M[Z]$ и $D[Z]$ (теоретически, экспериментально).

# %% [markdown]
# **Задача 5**
#
# Время обработки запроса на первом сервере имеет распределение Эрланга 2-го порядка с параметром $\lambda = 2$, на втором — Эрланга 3-го порядка с тем же $\lambda = 2$. Найти распределение суммарного времени обработки $Z = X + Y$. Вычислить $M[Z]$ и $D[Z]$ (теоретически, экспериментально).

# %% [markdown]
# ## 3. Дискретные, непрерывные случайные величины и их характеристики

# %% [markdown]
# **Задание 1**
#
# В компьютерной системе генерируются три типа пакетов данных: $X_1$ (служебные), $X_2$ (аудио) и $X_3$ (видео). Количество пакетов каждого типа — независимые целочисленные неотрицательные случайные величины. Распределения величин заданы таблицами (значения $x$ и вероятности $p$):
#
# $X_1$ (Служебные): $P(0)=0.3$, $P(1)=0.5$, $P(3)=0.2$.
#
# $X_2$ (Аудио): $P(1)=0.4$, $P(2)=0.4$, $P(4)=0.2$.
#
# $X_3$ (Видео): $P(0)=0.1$, $P(2)=0.6$, $P(5)=0.3$.
#
# Найти математическое ожидание, дисперсию, среднее квадратическое отклонение и коэффициент вариации суммарного потока пакетов $S = X_1 + X_2 + X_3$ двумя способами: теоретически (используя свойства матожидания и дисперсии суммы независимых величин, а также через производящую функцию) и численно (путем построения ряда распределения для $S$).

# %% [markdown]
# **Задание 2**
#
# Поток запросов к веб-серверу описывается суммой трех независимых пуассоновских процессов:
#
# $X_1$ — запросы на чтение данных со средним $\lambda_1 = 2$ запроса в секунду.
#
# $X_2$ — запросы на запись данных со средним $\lambda_2 = 1$ запрос в секунду.
#
# $X_3$ — запросы на аутентификацию со средним $\lambda_3 = 0.5$ запроса в секунду.
#
# Найти математическое ожидание, дисперсию, среднее квадратическое отклонение и коэффициент вариации общего числа запросов $S = X_1 + X_2 + X_3$ за одну секунду. Выполнить расчет теоретически и подтвердить результат численным моделированием (например, сгенерировав выборку и вычислив статистики).

# %% [markdown]
# **Задание 3**
#
# Пакет данных передается по каналу связи, состоящему из $K$ последовательно включенных линий ($K=3$). Время передачи пакета по каждой линии распределено экспоненциально со средним значением $T_i$:
#
# Линия 1: $T_1 = 10$ мс ($\lambda_1 = 0.1$).
#
# Линия 2: $T_2 = 20$ мс ($\lambda_2 = 0.05$).
#
# Линия 3: $T_3 = 5$ мс ($\lambda_3 = 0.2$).
#
# Найти преобразование Лапласа-Стилтьеса (ПЛС) распределения времени передачи пакета через весь канал, а также его математическое ожидание и дисперсию. Построить имитационную модель процесса передачи и сравнить теоретические результаты с выборочными характеристиками.

# %% [markdown]
# **Задание 4**
#
# В колл-центр поступают три независимых потока вызовов: $X_1$ (техподдержка), $X_2$ (отдел продаж), $X_3$ (отдел качества). Интервалы времени между вызовами распределены экспоненциально с параметрами $\lambda_1 = 0.1$, $\lambda_2 = 0.25$, $\lambda_3 = 0.15$ звонков в минуту соответственно.
#
# Найти распределение суммарного потока вызовов в минуту $S = X_1 + X_2 + X_3$.
#
# Вычислить вероятность того, что за минуту поступит не более 2 вызовов.
#
# Найти $M[S]$, $D[S]$, СКО и коэффициент вариации. Построить имитационную модель процесса передачи и сравнить теоретические результаты с выборочными характеристиками.

# %% [markdown]
# **Задание 5**
#
# В систему поступают два независимых пуассоновских потока заявок: $X_1 \sim Pois(5)$ и $X_2 \sim Pois(3)$. Система может обработать не более 10 заявок в единицу времени. Если сумма $S = X_1 + X_2$ превышает 10, то "лишние" заявки теряются.
#
# Найти распределение числа обработанных заявок $Y = \min(S, 10)$.
#
# Вычислить $M[Y]$, $D[Y]$ и вероятность потери заявки $P(S > 10)$.
#
# Найти условное математическое ожидание $M[S | S > 10]$. Построить имитационную модель процесса передачи и сравнить теоретические результаты с выборочными характеристиками.

# %% [markdown]
# ## Генерация задания

# %%
Variant<-1
group <-81
set.seed(Variant+2026+group+24656) 
c(sample(1:6,1),sample(1:5,1),sample(1:5,1))
# Out:
# [1] 5 4 3
